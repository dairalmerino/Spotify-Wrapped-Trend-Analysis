# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# * Tamika Hsieh: Project management (Analysis Write-up, Video), Writing - drafting, Data visualization, Summarization & Analysis
# * Anushka Joshi: Background Research, Writing - drafting, visulization, Video preparation
# * Daira: Merino: Coding & Data gathering, Analysis, Visualization
# * Gianna Hester: Coding & Data gathering, backgroudn research, Video preparation
# * Dellaena Malsizewski: Project Management (Data), coding, data wrangling and gathering, background research

# %% [markdown]
# ## Research Question

# %% [markdown]
# Similarities in a song's danceabilty, valence, ad energy rating can be statistically significant when examined across different release years because these ratings demonstrate traits that set the foundation for why songs become popular. The higher ratings in any of these categories is indicative of a higher likelihood that the song will be popular and, if the ratings are all similarly high or low, it is likely to that the song can return to popularity or "comeback".
#
# Therefore, we can use pairwise comparisons for each variable across different release years to understand how the numeric similarities of these ratings compare using adjusted p-values and confidence intervals to assist in our understanding of what could be statistically significant in how songs become popular enough to top the Billboard charts or key industry indicators like 2025 Spotify Wrapped list.
#
# Every year in December 6 million Spotify users get a list called "Spotify Wrapped" which highlights the 100 most played songs by Spotify users during the year regardless of the song's release date. The struggling music industry invests in teams of analysts who use Spotify Wrapped data to understand music, cultural and data trends that could indicate the "next big comeback" of songs or artists from certain publishing years. These songs are measured using the Spotify audio feature 0.0–1.0 using the following categories: danceability (how easy it is to dance to), energy (intensity and activity during the song), and valence (musical positivity throughout the song). We will use these variables as well as the following variables: Release date (release_year), to answer the following question:
#
# In 2025, do the top 100 songs included in the 2025 Spotify Wrapped list share statistically signficant similarities in danceability, valence, and energy according to their release date which could indicate a potential "comeback"?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# > Spotify started as a small start-up in Stockholm, Sweden. They started as a response to the growing issues of piracy and intellectual property theft in the music industry (<a name="cite_note-6">source</a>). Their solution was to create a platform where artists could earn revenue from people streaming their songs <a name="cite_note-1">(source)</a> This was not without controversy and competition though, as Apple Music signed exclusive contracts with big name artists to get the chance to stream their music first <a name="cite_note-7">(source)</a>. In addition, many artists like Taylor Swift and Jay-Z pulled their music from the platform previously, claiming that Spotify was underpaying the artists, and that it was just an experiment(BBC) <a name="cite_note-4">(source)</a>. Ten years ago in 2016, Spotify Wrapped burst into the scene, providing users with data that summarized their past listening activity for a given year <a name="cite_note-3">(source)</a>. This marketing strategy profited off of the need for users to feel included and validated for their listening hours and music taste. Since the inception of Spotify Wrapped, they have been slightly tweaking a few of the "categories", categorizing people in a more subjective, seemingly random, way <a name="cite_note-2">(Petridis)</a>.
#
# > Spotify Wrapped has drawn an increasing amount of attention in the more recent years, and with this attention, came people challenging the validity and ethics of the sensation (<a name="cite_note-8">source</a>). Because Spotify Wrapped uses LLMs and algorithmic data, it can often be inaccurate or biased(<a name="cite_note-8">source</a>). Users frequently report that the algorithm favors shorter songs over longer ones, reporting frequency over total listening time (<a name="cite_note-8">source</a>). The biggest elephant in the room is the fact that it shows how much this large company is surveilling users, and how much data they can get off of someone <a name="cite_note-2">(Petridis)</a>. The shiny bow of Wrapped also hides the fact that many artists on the platform are still underpaid for their work<a name="cite_note-2">(Petridis)</a>. With the surge of AI in the world, it is also apparent that Spotify Wrapped and Spotify in general rely heavily on AI for insights into listening activity <a name="cite_note-2">(Petridis)</a>.
#
# > We are looking into this now because the impact of streaming services like Spotify is a double edged sword for artists. According to statistics, the physical sale of music has gone down, while streaming has boomed<a name="cite_note-5">(Kiger)</a>. The benefits of Spotify Wrapped for artists include providing them with statistics about their audience demographic, which albums are streamed the most, and in what contexts their music is listened in (Spotify Newsroom)<a name="cite_note-5">(Kiger)</a>. Some downsides of Spotify's growth on the music industry, is the predatory practices they promote. Their new policies regarding what counds as a "stream" for artists largely only benefit large record labels and hurt small creators uploading for the first time <a name="cite_note-4">(source)</a>. The Michigan Economic journal found that Spotify's new streaming reveune rules only benefit large labels that exploit their artists<a name="cite_note-4">(source)</a>. A benefit though, of the vast variety that Spotify provides for its users, is that people are able to have more variation in their music taste. This might allow people to find smaller artists that they like, something that was less common with buying physical CDs <a name="cite_note-5">(Kiger)</a>.
#
# > Some previous examples of analysis, datasets and studies that have been conducted include "Wrap your head around it: algorithmic self-making and performances of taste on Spotify Wrapped" which provides data driven evidence that Spotify Wrapped lists are not random ( <a name="cite_note-8">(Valiati, V., Lupinacci, L., & Soares, 2026)</a>). Rather they are socially and algorithmically shaped and also have significant overlap across users’ top songs ( <a name="cite_note-8">(Valiati, V., Lupinacci, L., & Soares, 2026)</a>). The findings about the algorithm also suggest that the audio features of Spotify Wrapped songs may reflect what listeners strategically choose to listen to but it does not have to be something that they enjoy ( <a name="cite_note-8">(Valiati, V., Lupinacci, L., & Soares, 2026)</a>). If millions of people listen to the same songs despite having their personalized lists, those songs must share properties which make them so much appealing to a broader audience ( <a name="cite_note-8">(Valiati, V., Lupinacci, L., & Soares, 2026)</a>). We intend on analyzing whether the audio profiles of Spotify Wrapped Top 100 songs are actually similar based on standardized variables to each other than they would be by chance, and if this similarity varies by release years.
#
# > In another study, "Spotify (Un)wrapped: how ordinary users critically reflect on Spotify's datafication of the self within creative workshops",  researchers examine user reflections on how Spotify turns personal behavior into data stories ("datafication of the self") <a name="cite_note-9">(Annabell & Rasmussen, 2024)</a>. This study is supported by  additional findings that Spotify’s own listener typologies are built from the core variables that we will be using in our project: danceability, energy, and valence (<a name="cite_note-10">source</a>). It also shows Spotify’s internal audio feature categories are connected to the behavioral and cultural processes which determine what is displayed in Wrapped (<a name="cite_note-10">source</a>). “Wrappification” gives an explanation for why the Wrapped 100 should show a non-random audio feature pattern in which the platform selects songs that fit in the listener template defined by features like danceability, valence, and energy (<a name="cite_note-10">source</a>). We intend to analyze patterns in audio features by their release years are not trends but factors of how Spotify structures the listener type, and how certain songs fit in these types and how some don't.
#
# > In the final study uncovered in our background research, "Spotify ‘Unwrapped’: An Exploration of Data-Based Value Generation on a Music Streaming Platform" (<a name="cite_note-10">Adenuga, 2022</a>), a music industry analyst investigates the value creation of Spotify Wrapped for Spotify, artists, and advertisers. In this study, Adenuga validates that the music industry already uses Spotify Wrapped data for market intelligence which makes it a highly valuable asset(<a name="cite_note-10">Adenuga, 2022</a>). Spotify uses large amounts of user data to personalize music, promote artists, and also help advertisers target the intended audience. Spotify creates value for many groups, for example, songs that again become popular might create additional money in the music industry (<a name="cite_note-10">Adenuga, 2022</a>). This value proposition directly supports the urgency and importance of our project.
#
# 1. [^](#cite_ref-1) How Spotify came to be worth billions. *BBC*. https://www.bbc.com/news/newsbeat-43240886
# 2. [^](#cite_ref-2) Petridis, Alex. Spotify Wrapped is creepy, meaningless – and shows just how much data big tech has on you. *The Guardian*. https://www.theguardian.com/music/2023/nov/30/spotify-wrapped-is-creepy-meaningless-and-shows-just-how-much-data-big-tech-has-on-you
# 3. [^](#cite_ref-3) The 2025 Wrapped Guide for Artists, Songwriters, Creators, Authors, and Advertisers. *Spotify Newsroom*. https://newsroom.spotify.com/2025-12-03/wrapped-for-artists-songwriters-creators-authors-advertisers/
# 4. [^](#cite_ref-4) Smith, Niko. Spotify and the War on Artists. *Michigan Journal of Economics*. https://sites.lsa.umich.edu/mje/2024/01/29/spotify-and-the-war-on-artists/
# 5. [^](#cite_ref-5) Kiger, Patrick. How Spotify Broadens Your Musical Tastes. *Stanford Business*. https://www.gsb.stanford.edu/insights/how-spotify-broadens-your-musical-tastes
# 6. [^](#cite_ref-6) *Spotify Support Article*. https://support.spotify.com/us/article/what-is-spotify/
# 7. [^](#cite_ref-7) Greenberg, C. (10 Dec 2024) The origin and evolution of Spotify’s Wrapped *Medium*. https://medium.com/@candice.katz/the-origin-and-evolution-of-spotifys-wrapped-ab44805bfb93
# 8. [^](#cite_ref-8) Valiati, V., Lupinacci, L., & Soares, F. B. (2026). Wrap your head around it: algorithmic self-making and performances of taste on Spotify Wrapped. Information Communication & Society, 1–22. https://doi.org/10.1080/1369118x.2026.2647352
# 9. [^](#cite_ref-9) Annabell, T., & Rasmussen, N. V. (2024). Spotify (Un)wrapped: how ordinary users critically reflect on Spotify’s datafication of the self within creative workshops. Journal of Gender Studies, 34(8), 1177–1193. https://doi.org/10.1080/09589236.2024.2433674
# 10. [^](#cite_ref-10) Annabell, T., & Rasmussen, N. V. (2025). An algorithmic event: The celebration and critique of Spotify Wrapped. New Media & Society. https://doi.org/10.1177/14614448251391301
# 11. [^](#cite_ref-10)Adenuga, A. (2022, November 18). Spotify ‘Unwrapped’: An Exploration of Data-Based Value Generation on a music streaming platform. iSCHANNEL. https://ischannel.lse.ac.uk/articles/198

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# By analyzing and synthesizing the top 100 songs included in the 2025 Spotify Wrapped list, we believe the research will demonstrate that there are similarities between songs by release date such that directional trends will emerge.
#
# From our analysis, we believe that there will be directional predictions for each audio feature. We predict that danceability will differ the most by release year due to songs which are popular, but may not be suited specifically for dancing. We also predict that the most consistent variable that will not differ too much by release year will be valence because upbeat and happy qualities of music is, unlike danceability, often listened to regardless of activity performed. The final variable, energy, will demonstrate moderate variability because this variable tends to be genre specific to high energy genres of music like techno or house music which are also subject to confounding variables like digital media platforms like TikTok which can play clips of music over and over in an upbeat, high energy video.
#
# We also suspect that there will be certain confounding variables present across all of the variables such as the rise in popularity of TikTok which could potentially artifically positively influence the number of listens for certain artists present on the 2025 Spotify Wrapped list or account for outliers.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
# In summary, we chose a core dataset, Spotify Wrapped 2025 | Top Songs & Artist Dataset, and two additional datasets, TikTok Popular Songs (2020-2022), and Billboard Top 100, in order to understand potential confounding variables to our hypotehsis.
#
# #### Process for cleaning each dataset includes:
# * Creating a clear and specific overview of each dataset and how it supports our project
# * Extracting the dataset from kaggle, the source for each dataset
# * Getting an initial description of the dataset using the **.info()** method
# * Selecting which columns to keep that represented the most relevant data and variables included in our project using the **col_to_keep method**
# * Updating the release year or date using the **to_datetime method**
# * Checking for missing data across all of the variables we chose to keep using the **isnull().sum() method** and the **df.dropna() method** to remove records with missing values as needed
# * Using a box plot to visually check for any outliers
# * Providing explanations for these outliers using markdown
# * Checking for duplicates using the **describe()** and **duplicated().sum() method**
# * Removing duplicates, if necessary using the **drop_duplicates() method**
# * Adding the cleaned data back into the interim and processed folders in Github when complete using the **to_csv method**
#
# #### Process for enjoining the data includes:
# * Using song or track name as a primary unique identfier for the songs such that we can compare songs across the datasets
# * Using the release year as a secondary unique identifier to ensure we are comparing the right metrics to the correct song as some songs may experience multiple releases.
#
# **For the TikTok Dataset**
# * Songs which do not match up to a primary and secondary unique identifier (Song name, release year) will be included in the final data set if they are in the core data set (Spotify Wrapped 2025 | Top Songs & Artist Dataset).
# * Songs which do not match up to a primary and secondary unique identifier (Song name, release year) will be excluded from the final confounding variable analysis because we are examining the impact of confounding variables on songs present in our core data set (Spotify Wrapped 2025 | Top Songs & Artist Dataset) and therefore do not want o introduce additional noise that could skew our model.
#
# **For the Billboard Top 100 Dataset**
# * In order to join this dataset we will need to use Song Name as the primary unique identifier and the artist name as the secondary unique identifier because this dataset does not include release year.
# * We expect that this dataset will provide more details about other potential confounding variables because it includes dates based on sales, radio airplay, and streaming platforms other than Spotify while also including our primary metrics which could support and validate our hypothesis.
# * In addition to being able to explore potential additional confounding variables, we expect that this dataset will help us confirm that popularity of a song such that a "comeback" could be established using the number of times the song made the Billboard Top 100 chart as a proof point of growing popularity.
#
# By using these variables we will be able to match the specific songs and it's ratings for danceability, valence, and energy across all of our datasets while also ensuring that if the song was rereleased for some reason, that the ratings will follow the correct song under the correct release date. This will also allow us to us the pairwise comparison method that will help us understand variability within our metrics by release year.
#
# **Kaggle Account**
# In order to replicate extracting data from Kaggle you need to have your own Kaggle account and be logged in at the time of running your code. The code below includes in the installing of Kaggle and pulls our data from Github, but you will still need your own account and be logged in if you want to extract your own datasets from Kaggle.

# %% [markdown]
# ##  Dataset #1 - Spotify Wrapped 2025 | Top Songs & Artist Dataset
#
# This dataset captures the top 200 songs and artists according to the 2025 Spotify Wrapped play list plus the all-time most streamed songs in Spotify history up to March 2026. The 2025 Spotify Wrapped list reflects the most popular streams, regardless of release date, that were streamed from January 1, 2025 to October 31, 2025 according to the [Spotify Wrapped measurement window](https://newsroom.spotify.com/2025-12-05/wrapped-methodology-explained/). In this dataset, the monthly listener counts for artists are a point in time up to March 2026 and all-time stream counts reflect totals January 1st, 2025 to March 2026.
#
# It was created by [Syed Ali Taqi](https://www.kaggle.com/alitaqishah) who is a statistician at Comsats University in Pakistan. The dataset contains 200 entries and 14 variables (described below).
#
# In this project, the "Spotify Wrapped 2025 | Top Songs & Artist Dataset" serves as our base dataset for the exploration of our research question and hypothesis validation. We will examine danceability, valence, and energy by release year to understand if there are significant differences in these variables by release year.
#
# ### Metrics
#
# - **song_title:** The name of the song
# - **artist:** The main artist and any featured artists in the song
# - **streams_2025_billions:** The total number of streams in 2025 (billions), January 1, 2025 to October 31, 2025
# - **total_streams_billions:**	The all-time total streams (billions), up to March 2026
# - **primary_genre:** The main genre that the music was classified under
# - **bpm:** The beats per minute (tempo) of the song
# - **duration_seconds:** The length of the song (seconds)
# - **release_year:** The year the song was originally released
# - **artist_country:** The country of origin for the primary artist
# - **explicit:** Determination if the the song contains explicit content
# - **danceability:** Rated using the Spotify audio feature 0.0–1.0 and how suitable the song is for dancing
# - **energy:** Rated using the Spotify audio feature 0.0–1.0 and is a reference to the intensity and activity of the song
# - **valence:** Rated using the Spotify audio feature 0.0–1.0 and represents the musical positivity of the song
# - **acousticness:** Rated using the Spotify audio feature 0.0–1.0 and references that acoustic vs electronic composition of the song.
# - **peak_global_chart_position:** The highest position reached on Spotify Global Chart up to March 2026
#
# ### Limitations and Concerns
#
# This dataset primarily reflects Spotify Wrapped metrics and trends for the year 2025, which does not account for previous years even though the release dates extend beyond 2025. This limitation might demonstrate bias against newer songs with release dates before 2025 because the songs with earlier release dates have has more time to accumulate streams and poluarity than newly released songs. This bias would apply to all songs with a release date before or in 2020 representing 50% of the dataset (100 songs) and a five year popularity window where the relevant variables could be more readily normalized against 2025.

# %%
import pandas as pd
import sys
from scipy import stats
import matplotlib.pyplot as plt

# %%
#conda install -c conda-forge pandas

# %%
#%pip install kaggle

# %%
##Extract the data
sys.path.append('./modules')

#%pip install kaggle 

import subprocess
subprocess.run([
    "kaggle", "datasets", "download",
    "-d", "alitaqishah/spotify-wrapped-2025-top-songs-and-artists",
    "-p", "data/00-raw/",
    "--unzip"
], check =True)


spotify_wrapped_df = pd.read_csv('data/00-raw/spotify_wrapped_2025_top50_songs.csv')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/alitaqishah/spotify-wrapped-2025-top-songs-and-artists
# License(s): CC0-1.0
# ...
# 100%|██████████| 8.36k/8.36k [00:00<00:00, 7.91MB/s]

# %%
##Choose which columns we want to keep
spotify_wrapped_df.columns

col_to_keep = ['song_title','artist','release_year','danceability','energy',
               'valence','primary_genre','acousticness','peak_global_chart_position']

spotify_wrapped_clean = spotify_wrapped_df[col_to_keep].copy()

# %%
## Get initial information about the dataset
spotify_wrapped_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   song_title                  50 non-null     object
#  1   artist                      50 non-null     object
#  2   release_year                50 non-null     int64
#  3   danceability                50 non-null     float64
#  4   energy                      50 non-null     float64
#  5   valence                     50 non-null     float64
#  6   primary_genre               50 non-null     object
#  7   acousticness                50 non-null     float64
#  8   peak_global_chart_position  50 non-null     int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 3.6+ KB

# %%
spotify_wrapped_clean.head(5)
# Out:
#              song_title                  artist  release_year  danceability  \
# 0      Die With A Smile  Lady Gaga & Bruno Mars          2024          0.72
# 1                  APT.       ROSE & Bruno Mars          2024          0.86
# 2              Espresso       Sabrina Carpenter          2024          0.80
# 3  Please Please Please       Sabrina Carpenter          2024          0.70
# 4                 Taste       Sabrina Carpenter          2024          0.78
#
#    energy  valence primary_genre  acousticness  peak_global_chart_position
# 0    0.68     0.55           Pop          0.18                           1
# 1    0.79     0.88     K-Pop/Pop          0.05                           1
# 2    0.73     0.96           Pop          0.06                           1
# 3    0.66     0.87           Pop          0.10                           1
# 4    0.70     0.82           Pop          0.08                           1

# %%
## Check for any missing values in the dataset
spotify_wrapped_clean.isnull().sum()
# Out:
# song_title                    0
# artist                        0
# release_year                  0
# danceability                  0
# energy                        0
# valence                       0
# primary_genre                 0
# acousticness                  0
# peak_global_chart_position    0
# dtype: int64

# %% [markdown]
# No missing values from the dataset across all of the variables.

# %%
## Create the boxplot to visually check for outliers

spotify_wrapped_clean[['danceability','energy','valence']].boxplot(figsize=(10,6))
plt.title('Audio Feature Distribution')
plt.ylabel('Value (0-1 scale)')
plt.show()

# %% [markdown]
# The boxplot above reveals that there are no current outliers in this data set across our main variables: danceability, energy, and valence.

# %%
##Checking for duplicate records
spotify_wrapped_clean.describe()
spotify_wrapped_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There were no duplicates in this dataset.

# %%
## Provide resulting clean datasets to the iterim and processed folder
spotify_wrapped_clean.to_csv('data/01-interim/spotify_wrapped_2025_top50_songs_cleaned.csv', index=False)
spotify_wrapped_clean.to_csv('data/02-processed/spotify_wrapped_2025_top50_songs_final.csv', index=False)

# %% [markdown]
# ### Dataset #2 - TikTok Popular Songs (2020-2022)
#
# This dataset is a combination of three consecutive years of globally popular
# TikTok songs (2020, 2021, and 2022), each compiled by Kaggle user sveta151:
# - 2020: https://www.kaggle.com/datasets/sveta151/tiktok-popular-songs-2020
# - 2021: https://www.kaggle.com/datasets/sveta151/tiktok-popular-songs-2021
# - 2022: https://www.kaggle.com/datasets/sveta151/tiktok-popular-songs-2022
#
# The dataset contains 745 entries (744 after removing one duplicate) and 7
# variables. A `year` column was added to each dataset before combining to
# indicate the year the songs were trending on TikTok, not their release year.
#
# In this project, the TikTok dataset serves as a way to explore a potential
# confounding variable, TikTok virality, that may influence which songs appear
# on the 2025 Spotify Wrapped list. By comparing the audio features of TikTok
# trending songs across three consecutive years to those of Spotify Wrapped songs,
# we can assess whether TikTok consistently promotes songs with similar audio
# characteristics, and whether those characteristics align with what appeared on
# the 2025 Spotify Wrapped list.
#
# ### Metrics
#
# - **track_name**: The name of the song
# - **artist_name**: The name of the song's artist
# - **danceability**: How suitable a track is for dancing (0-1 scale; higher = more danceable)
# - **energy**: Perceptual measure of intensity and activity (0-1 scale; higher = more energetic)
# - **valence**: Musical positiveness of a track (0-1 scale; higher = more positive/happy)
# - **acousticness**: Confidence measure of whether a track is acoustic (0-1 scale; higher = more acoustic)
# - **year**: The year the song was trending on TikTok (2020, 2021, or 2022) — note this is not the song's release year
#
# ### Limitations and Concerns
#
# This dataset covers TikTok trending songs from 2020-2022, creating a time gap with our 2025 Spotify Wrapped data. However, research supports that the audio feature patterns TikTok promoted during this period established a blueprint that continues to shape music production today. According to TikTok themselves, their community has consistently gravitated toward songs that are "confident, empowering, sonically unique, and danceable" since 2020, and a Luminate study found that US TikTok users are twice as likely to discover music on short-form video platforms than the average user, indicating TikTok's influence on music discovery has only grown over time.
#
# Additionally, since the `year` column reflects when songs were trending on TikTok rather than their release year, some songs may have been released before their trending year. This is consistent with TikTok's known pattern of reviving older songs through viral trends.
#
# Boxplot analysis revealed outliers in danceability, acousticness, and energy, however all values fall within Spotify's defined 0-1 scale and represent genuine
# musical characteristics rather than data errors. One duplicate entry was found (Rags2Riches 2 by Rod Wave, appearing in both 2020 entries) and was removed, bringing the final dataset to 744 rows

# %%
## Extract the datasets
sys.path.append('./modules')

# Note: datasets were downloaded via Kaggle CLI in terminal
# To re-download, run in terminal with myenv activated:
# conda activate myenv
# kaggle datasets download -d sveta151/tiktok-popular-songs-2020 -p data/00-raw/ --unzip
# kaggle datasets download -d sveta151/tiktok-popular-songs-2021 -p data/00-raw/ --unzip
# kaggle datasets download -d sveta151/tiktok-popular-songs-2022 -p data/00-raw/ --unzip

tiktok_2020 = pd.read_csv('data/00-raw/TikTok_songs_2020.csv')
tiktok_2021 = pd.read_csv('data/00-raw/TikTok_songs_2021.csv')
tiktok_2022 = pd.read_csv('data/00-raw/TikTok_songs_2022.csv')

# %%
print('tiktok 2020: \n',tiktok_2020.columns,'\n')
print('tiktok 2021: \n', tiktok_2021.columns,'\n')
print('tiktok 2022: \n',tiktok_2022.columns,'\n')
# Out:
# tiktok 2020:
#  Index(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms'],
#       dtype='object')
#
# tiktok 2021:
#  Index(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms'],
#       dtype='object')
#
# tiktok 2022:
#  Index(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms'],
#       dtype='object')

# %%
cols_to_keep = ['track_name', 'artist_name', 'danceability', 'energy', 
                'valence', 'acousticness']

tiktok_2020 = tiktok_2020[cols_to_keep]
tiktok_2021 = tiktok_2021[cols_to_keep]
tiktok_2022 = tiktok_2022[cols_to_keep]

# Adding respective years of when these songs were trending on TikTok
tiktok_2020['year'] = 2020
tiktok_2021['year'] = 2021
tiktok_2022['year'] = 2022

# combining all three dataframes
tiktok_comb = pd.concat([tiktok_2020, tiktok_2021, tiktok_2022], ignore_index = True)
print(tiktok_comb.shape)
tiktok_comb.head()
# Out:
# (745, 7)
#                          track_name          artist_name  danceability  \
# 0                            Say So             Doja Cat         0.787
# 1                   Blinding Lights           The Weeknd         0.514
# 2  Supalonely (feat. Gus Dapperton)                BENEE         0.862
# 3                            Savage  Megan Thee Stallion         0.843
# 4                Moral of the Story                 Ashe         0.572
#
#    energy  valence  acousticness  year
# 0   0.673    0.779       0.26400  2020
# 1   0.730    0.334       0.00146  2020
# 2   0.631    0.841       0.29100  2020
# 3   0.741    0.680       0.02520  2020
# 4   0.406    0.265       0.58700  2020

# %%
## Get an overview of the dataset
tiktok_comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_name    745 non-null    object
#  1   artist_name   745 non-null    object
#  2   danceability  745 non-null    float64
#  3   energy        745 non-null    float64
#  4   valence       745 non-null    float64
#  5   acousticness  745 non-null    float64
#  6   year          745 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 40.9+ KB

# %%
## Check for missing values in the dataset
tiktok_comb.isnull().sum()
# Out:
# track_name      0
# artist_name     0
# danceability    0
# energy          0
# valence         0
# acousticness    0
# year            0
# dtype: int64

# %% [markdown]
# No missing values were found across all 7 columns of the TikTok Popular Songs (2020-2021) dataset, `tiktok_comb`.

# %%
## Create a box plot to visually check for outliers

tiktok_comb[['danceability','energy','valence', 'acousticness']].boxplot(figsize=(10,6))
plt.title('Audio Features Distribution')
plt.ylabel('Value (0-1 scale)')
plt.show()

# %% [markdown]
# Boxplot analysis revealed outliers in several audio features, particularly in danceability, energy, and acouticness. However, since all values fall within Spotify's defined 0-1 scale, these represent genuine musical charactertistic rather than data error.

# %%
## Identify and clean duplicates
print(tiktok_comb.describe(),'\n')
print('Duplicates: ', tiktok_comb.duplicated().sum())
# Out:
#        danceability      energy     valence  acousticness         year
# count    745.000000  745.000000  745.000000    745.000000   745.000000
# mean       0.717439    0.652750    0.535993      0.211385  2020.961074
# std        0.128110    0.155729    0.216822      0.234037     0.862815
# min        0.174000    0.045800    0.034800      0.000038  2020.000000
# 25%        0.650000    0.542000    0.383000      0.024800  2020.000000
# 50%        0.725000    0.673000    0.531000      0.123000  2021.000000
# 75%        0.802000    0.773000    0.711000      0.316000  2022.000000
# max        0.980000    0.989000    0.970000      0.974000  2022.000000
#
# Duplicates:  1

# %%
 # Checking what the dupicated actually are
tiktok_comb[tiktok_comb.duplicated(keep=False)].sort_values('track_name')
# Out:
#                          track_name artist_name  danceability  energy  \
# 133  Rags2Riches 2 (feat. Lil Baby)    Rod Wave         0.874   0.443
# 251  Rags2Riches 2 (feat. Lil Baby)    Rod Wave         0.874   0.443
#
#      valence  acousticness  year
# 133    0.298         0.147  2020
# 251    0.298         0.147  2020

# %%
tiktok_comb = tiktok_comb.drop_duplicates()
print(tiktok_comb.shape)
# Out:
# (744, 7)

# %% [markdown]
# The `tiktok_comb` dataset has one duplicate, Rags2Riches 2 (feat. Lil Baby) by Rod Wave, this duplicate was dropped, making reducing the number of rows in this dataset to 744.

# %%
## Provide resulting clean datasets to the iterim and processed folder
# tiktok_clean.to_csv('data/01-interim/tiktok_cleaned.csv', index=False)
# tiktok_clean.to_csv('data/02-processed/tiktok_final.csv', index = False)

# %% [markdown]
# ###  Dataset #3 - Billboard Hot-100[2000-2023] data with features dataset.
#
# This dataset captures the most popular songs to make the Billboard Hot 100 year-end charts in addition to adding the same audio variables from Spotify that we are evaluating in our project. This dataset includes songs from Billboard Hot-100 charts for the years 2000-2023. As context, Billboard Hot 100 chart is a weekly chart published by the music industry in the United States. This chart ranks the 100 most popular songs across all genres based on streaming, radio airplay, and sales data. We believe that because this chart shares the same variables in our core dataset, Spotify Wrapped 2025 | Top Songs & Artist Dataset, we will able to validate additional confounding variables which may impact the differences in our variables by release year.
#
# This dataseet was created by Kaggle user [suparnabiswas](https://www.kaggle.com/suparnabiswas) over two years ago with no additional source information available.
#
# In this project, the "Billboard Hot-100[2000-2023] data with features dataset" serves as an additional dataset with shich we can explore potential confounding variables because, in addition to using the same variables from our core dataset, it expands the data to include data from other channels such as radio, direct sales, and streaming platforms in addition to Spotify. This dataset could also help use establish the likelihood of a potential comeback by being able to associate the number of times that a song hit the Billboard Top 100 charts with the variability of our metrics by release date. This dataset also includes additional Spotify metrics which are not part of our core variables, but might also reveal confounding variables that impact our hypothesis such "acousticness" (which is also present across all of our datasets). We expect to find at least one or two additional confounding variables from this dataset that will result in impact on the variability of our metrics by release date such that valence and energy will experience the most impact because they are more ubiquitous and are not tied to a specific action like dancing.
#
# ### Metrics
#
# - **Rank of the song for the year:** The rank of the song on the Billboard Top 100 chart
# - **song:** The name of the song
# - **band_singer:** The main artist and any featured artists in the song
# - **songurl:** The url of the song on Genius
# - **title:** The name of the song
# - **url:** The url of the artist on Wikipedia
# - **year:** The year that the song was on the Billboard Top 100 Chart
# - **lyrics** The lyrics of the song translated by Genius
# - **uri:** The url of the song on Spotify
# - **danceability:** Rated using the Spotify audio feature 0.0–1.0 and how suitable the song is for dancing
# - **energy:** Rated using the Spotify audio feature 0.0–1.0 and is a reference to the intensity and activity of the song
# - **valence:** Rated using the Spotify audio feature 0.0–1.0 and represents the musical positivity of the song
# - **acousticness:** Rated using the Spotify audio feature 0.0–1.0 and references that acoustic vs electronic composition of the song.
# - **key:** The key that the song was produced in
# - **loudness:** The level of sound in the song
# - **mode:** Metric that tracks whether or not the song showed in a Spotify algorithm
# - **speechiness:** The presence of speech and talking in the song
# - **instrumentalness:** The presence of several instruments in the song
# - **liveness:** The presence of an audience in the song
# - **tempo:** The Tempo of the song
# - **type:** The type of anlaysis performed by the Spotify platform
# - **id:** The ID of the track on the Spotify platform
# - **track_href:** The URL to the track on the Spotify platform
# - **analysis_url:** The URL to the analysis from the Spotify platform
# - **duration_ms:** The duration of the song (milliseconds)
# - **time_signature:** The time signature of the song
#
# ### Limitations and Concerns
#
# The primary limitation is that this dataset does not provide the release year of the song and only uses the year in which the song hit the Billboard Top 100 chart. This limitation means that we cannot use the release data as a secondary unique identifier, so we will need to substitute the artist to ensure that we are comparing the right songs, release years and metrics.

# %%
#%pip install kaggle

# %%
##Extract the data
sys.path.append('./modules')

import subprocess
subprocess.run([
    "kaggle", "datasets", "download",
    "-d", "suparnabiswas/billboard-hot-1002000-2023-data-with-features",
    "-p", "data/00-raw/",
    "--unzip"
], check =True)


billboard_100_df = pd.read_csv('data/00-raw/billboard_24years_lyrics_spotify.csv')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/suparnabiswas/billboard-hot-1002000-2023-data-with-features
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# 100%|██████████| 1.93M/1.93M [00:00<00:00, 9.78MB/s]

# %%
##Choose which columns we want to keep
billboard_100_df.columns

col_to_keep = ['song','band_singer','year','danceability','energy',
               'valence','acousticness']

billboard_100_clean = billboard_100_df[col_to_keep].copy()

# %%
## Get initial information about the dataset
billboard_100_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3397 entries, 0 to 3396
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song          3397 non-null   object
#  1   band_singer   3397 non-null   object
#  2   year          3397 non-null   int64
#  3   danceability  486 non-null    float64
#  4   energy        486 non-null    float64
#  5   valence       486 non-null    float64
#  6   acousticness  486 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 185.9+ KB

# %%
## Updated Date Format for Release year
billboard_100_clean['year'] = pd.to_datetime(billboard_100_clean['year'], format ='mixed')

# %%
## Check for any missing values in the dataset
billboard_100_clean.isnull().sum()
# Out:
# song               0
# band_singer        0
# year               0
# danceability    2911
# energy          2911
# valence         2911
# acousticness    2911
# dtype: int64

# %% [markdown]
# From the above inspection, there are a lot of blank and missing values in danceability, energy, valence, and accousticness which will need to be removed.

# %%
billboard_100_clean= billboard_100_clean.dropna()

# %%
##QA our work with dropping the missing values
billboard_100_clean.isnull().sum()

billboard_100_clean.head()
# Out:
#            song band_singer                       year  danceability  energy  \
# 0       Breathe  Faith Hill 1970-01-01 00:00:00.000002         0.529   0.496
# 1        Smooth     Santana 1970-01-01 00:00:00.000002         0.609   0.923
# 2        Smooth  Rob Thomas 1970-01-01 00:00:00.000002         0.590   0.637
# 3   Maria Maria     Santana 1970-01-01 00:00:00.000002         0.777   0.601
# 5  I Wanna Know         Joe 1970-01-01 00:00:00.000002         0.725   0.487
#
#    valence  acousticness
# 0    0.278       0.17300
# 1    0.961       0.16000
# 2    0.724       0.00225
# 3    0.680       0.04060
# 5    0.599       0.26000

# %%
## Create a box plot to visually check for outliers

billboard_100_clean[['danceability','energy','valence']].boxplot(figsize=(10,6))
plt.title('Audio Features Distribution')
plt.ylabel('Value (0-1 scale)')
plt.show()

# %% [markdown]
# From the above visualization, there is a concentration of outliers in the danceabiliy category, but these are standardized metrics from the Spotify platform and, because we're using this datat to examine confounding variables, the outliers are acceptable in this case but noted for final analysis with our core dataset.

# %%
##Checking for duplicate records
billboard_100_clean.describe()
billboard_100_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicate records in this dataset.

# %%
## Provide resulting clean datasets to the iterim and processed folder
billboard_100_clean.to_csv('data/01-interim/billboard_24years_lyrics_spotify_cleaned.csv', index=False)
billboard_100_clean.to_csv('data/02-processed/billboard_24years_lyrics_spotify_final.csv', index = False)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Analysis of our Core Dataset: Spotify Wrapped 2025 | Top Songs & Artists
#
# Below is the analysis of our core dataset Spotify Wrapped 2025 | Top Songs & Artists using pairwise comparisons and histograms for analysis. In this analysis we will compare all three variables using pairwise comparisons. Then, we will analyze each variable (energy, danceability, valence) alongside peak chart position to be able to validate or invalidate our hypothesis that these variables are statistically significant in whether or not there will be a "comeback" or resurgence in popularity.

# %%
spotifyData = pd.read_csv('data/02-processed/spotify_wrapped_2025_top50_songs_final.csv')
spotifyData.head()
# Out:
#              song_title                  artist  release_year  danceability  \
# 0      Die With A Smile  Lady Gaga & Bruno Mars          2024          0.72
# 1                  APT.       ROSE & Bruno Mars          2024          0.86
# 2              Espresso       Sabrina Carpenter          2024          0.80
# 3  Please Please Please       Sabrina Carpenter          2024          0.70
# 4                 Taste       Sabrina Carpenter          2024          0.78
#
#    energy  valence primary_genre  acousticness  peak_global_chart_position
# 0    0.68     0.55           Pop          0.18                           1
# 1    0.79     0.88     K-Pop/Pop          0.05                           1
# 2    0.73     0.96           Pop          0.06                           1
# 3    0.66     0.87           Pop          0.10                           1
# 4    0.70     0.82           Pop          0.08                           1

# %%
pairwise_spotifyData = sns.pairplot(spotifyData, vars = ['danceability', 'energy', 'valence'])
plt.show()

# %% [markdown]
# ##### Spotify Wrapped Pairplot (danceability, energy, valence)
#
# ##### Histogram Observations:
#
# * The diagonal histograms show the individual distribution of each variable.
# * Danceability is concentrated between 0.6-0.85, which means that most top Spotify Wrapped songs are moderately danceable, while only a few songs have low danceability values
# * The distribution is left-skewed.
# * The histogram for energy is more uniformly spread across the range of 0.4-0.9, showing that energy is more variable among these top songs.
# * Valence has clusters around 0.5-0.6 and 0.8-0.9, creating a bimodal distribution with two peaks. This suggests that many songs are either moderately positive or very positive, with fewer songs falling in between.
#
# ##### Scatter plot Observations:
#
# * The danceability vs. energy scatter plot shows a weak positive trend. Songs with higher energy levels tend to also have higher danceability.
# * The danceability vs. valence scatter plot does not show a strong linear relationship, suggesting that songs can be danceable regardless of whether they are emotionally positive or not.
# *  Energy vs. valence also shows no strong correlation.
# * Overall, the scatter plots suggest that the three variables are relatively independent of one another.

# %%
spotifyDataHistogramDance = sns.histplot(data=spotifyData, x="peak_global_chart_position", y="danceability",  cbar=True)
spotifyDataHistogramDance.set(xlabel='peak global chart position')
spotifyDataHistogramDance.set_title('Danceability vs. Peak Global Chart Position')
plt.show()

# %% [markdown]
# #### Danceability vs. Peak Global Chart Position Analysis
#
# The light-to-dark blue gradients indicate the density of songs at each combination, where darker shades represent a higher concentration of songs. Chart positions 1 through 5, with danceability values between 0.65-0.85, show the heaviest concentration. This suggests that the majority of songs ranked highest globally had moderate-to-high danceability values.
#
# There are almost no songs with danceability values below 0.5 at any chart position, indicating that danceability is likely an important factor for songs that achieve global chart success.
#
# There is also an outlier cluster around chart positions 20-22 with danceability values near 0.7. These songs charted well but at lower positions, possibly representing “comeback” songs from earlier release years. Their danceability still falls within the mid-to-high range, which is consistent with the rest of the top songs.
#
# This suggests that when older songs regain popularity, they tend to share similar danceability characteristics with newly released successful songs.

# %%
spotifyDataHistogramValence = sns.histplot(data=spotifyData, x="peak_global_chart_position", y="valence",  cbar=True)
spotifyDataHistogramValence.set(xlabel='peak global chart position')
spotifyDataHistogramValence.set_title('Valence vs. Peak Global Chart Position')
plt.show()

# %% [markdown]
# #### Valence vs. Peak Global Chart Position
#
# Unlike danceability, valence values at chart positions 1 to 5 are spread widely from approximately 0.6 to 0.95. This broad spread suggests that emotional positivity is not as strong of a determining factor for global chart success as danceability.
#
# Songs do not necessarily need to sound happy in order to reach the top of the charts. However, positions 1 to 3 show the darkest concentrations at valence values between 0.8-0.95, indicating that highly positive songs are still capable of achieving top chart positions.
#
# Compared to danceability, there is greater tolerance for moderate valence levels among successful songs. There is also an outlier cluster near position 22 with lower valence values around 0.2-0.5. These may represent slower or more melancholic songs that charted later in the year or older releases that experienced a resurgence in popularity.

# %%
spotifyDataHistogramEnergy = sns.histplot(data=spotifyData, x="peak_global_chart_position", y="energy",  cbar=True)
spotifyDataHistogramEnergy.set(xlabel='peak global chart position')
spotifyDataHistogramEnergy.set_title('Energy vs. Peak Global Chart Position')
plt.show()

# %% [markdown]
# #### Energy vs. Peak Global Chart Position
#
# Songs at the highest chart positions, ranging from 1 to 5, form dense clusters between energy values of 0.65-0.85, with the darkest cells concentrated in that range. Unlike danceability, there are also lower-energy songs with values around 0.4-0.55 that appear near the top positions. This suggests that energy, compared to danceability, is more flexible in terms of chart success.
#
# Compared with danceability, energy has a broader spread across positions 1 to 5, which aligns with the hypothesis that energy would show moderate variability. There are almost no songs with energy values below 0.4 at any chart position, suggesting that there is still a minimum energy threshold for chart success, although it is lower than the threshold for danceability.
#
# The cluster at position 22 appears to have mid-range energy values and is generally consistent with the pattern observed in the previous two charts.

# %% [markdown]
# #### Summary of Findings
# As a summary of findings in our core dataset include observations from our piarwise analysis (Histograms, scatterplots) as well as individual analysis for each variable (danceability, valence, and energy) coupled with the peak global chart position analysis. From this analysis, there is a strong relationship betwen songs on the Spotify Wrapped Top 50 which also have a high danceability and energy which indicates that these variables have a significant and consistent impact on the overall popularity of popular songs.
#
# ##### Interpretation
# One way that we can interpret these results is using the distribution of Audio Features. First, let's take a look at the danceability variable which is heavily left-skewed, peaking between 0.6 and 0.85. Because it is so heavily skewed, it validates our hypothesis that this variable would have an impact on whether or not a song could gain popularity and potentially make a comeback. Next, the energy variable, was more uniformly spread between 0.4 and 0.9. THis more uuniform distribution demonstrates less influence of this variable on the overall popularity and therefore it is unlikely that it has an impact on the popualrity of a song. Lastly, the variable for valence has a bimodal distribution that peaks at 0.5–0.6 and 0.8–0.9. However, the variables showed a weak linear relationship between all three.
#
# ##### Impact on Global Chart Position
# When we consider the impact of these variables on Global Chart position, we consider how the variables influence whether or not the song was able to also top the charts and which variables could have a statistically significant correlation to songs which ascended the global chart positions. With the danceability variable, this variable has the strongest correlation because Global Chart Positions 1–5 concentrate heavily at a danceability amount between 0.65–0.85. Additionally, there are almost no top songs below 0.5 in danceability which indicates that this variable is not only significant, but could also be a bounding variable which serves to set a minimum value. The next variable, energy, has important clusters, but is also flexible because most of the top songs on the Global Chart position  cluster at 0.65–0.85. However, unlike with danceability, there are still chart topping successful songs with lower energy levels which score down to a minimum threshold of 0.4. The last variable, valence, is the least impactful variable which can be observed in the data when songs at the top of the global charts have a wide span from 0.6 to 0.95. However, the songs with the highest global chart positions have a higher correlation of 0.8–0.95 in valence.
#
# ##### Important Outliers
# There is an outlier around the 22nd Global Chart position where there is a cluster of variables which represent older, resurrected hits and this is a an interesting observation in the data as we consider the opportunities for older songs to make a "comeback".

# %% [markdown]
# #### Exploring Confounding Variables:
#
# ### Billboard Top 100 Dataset Confounding Variable Analysis
#
# In this section we will explore some potential confounding variables using data provided in the Billboard Top 100 dataset. In order to accomplish this, we will use pairwise comparisons between our core dataset and the Billboard Top 100 Dataset.

# %%
billboardData = pd.read_csv('data/02-processed/billboard_24years_lyrics_spotify_final.csv')
billboardData.head()
# Out:
#            song band_singer                           year  danceability  \
# 0       Breathe  Faith Hill  1970-01-01 00:00:00.000002000         0.529
# 1        Smooth     Santana  1970-01-01 00:00:00.000002000         0.609
# 2        Smooth  Rob Thomas  1970-01-01 00:00:00.000002000         0.590
# 3   Maria Maria     Santana  1970-01-01 00:00:00.000002000         0.777
# 4  I Wanna Know         Joe  1970-01-01 00:00:00.000002000         0.725
#
#    energy  valence  acousticness
# 0   0.496    0.278       0.17300
# 1   0.923    0.961       0.16000
# 2   0.637    0.724       0.00225
# 3   0.601    0.680       0.04060
# 4   0.487    0.599       0.26000

# %%
pairwise_billboardData = sns.pairplot(billboardData, vars = ['danceability', 'energy', 'valence'])
plt.show()

# %% [markdown]
# #### Billboard Data Pairplot (danceability, energy, valence)
#
# ##### Histogram Observations:
#
# * Danceability’s histogram is centered around 0.6-0.75 with both sides gradually getting thinner. This Billboard data has a more spread out and symmetric distribution as compared to the Spotify Wrapped pairplot in which the danceability was more concentrated at the higher end. The Billboard data spans across 23 years of charting songs and a wider range of danceability levels have been successful.
#
# * Energy’s histogram is left-skewed and has a heavy concentration between 0.6-0.9 with a sharp drop-off below 0.4. This is more skewed than Spotify Wrapped energy distribution which shows that high energy is consistent in Billboard charting songs from 2000-2023 and not just recently.
#
# * Valence’s histogram is more flat and uniform than Spotify Wrapped data, spreading evenly from 0.2 to 0.9. This proves that Billboard chart success over the 23-year period has been achieved by songs of different genres, making valence the least constrained feature.
#
# ##### Scatter plot Observations:
#
# * Danceability vs. energy scatter plot shows a weak positive trend but has a huge scatter, which confirms that they are mostly independent.
# * Danceability vs. valence scatter plot shows no relationship and points are uniformly scattered.
# * Energy vs. valence similarly does not show any correlation.analysis

# %%
# Create comparison table
comparison = pd.DataFrame({
    'Billboard Hot 100': billboardData[['danceability', 'energy', 'valence']].mean(),
    'Spotify Wrapped 2025': spotifyData[['danceability', 'energy', 'valence']].mean(),
    'Difference': billboardData[['danceability', 'energy', 'valence']].mean() - spotifyData[['danceability', 'energy', 'valence']].mean()
})

print(comparison.round(3))
# Out:
#               Billboard Hot 100  Spotify Wrapped 2025  Difference
# danceability              0.667                 0.682      -0.014
# energy                    0.685                 0.647       0.038
# valence                   0.600                 0.666      -0.066

# %%
# Mann-Whitney U test for each feature
for feature in ['danceability', 'energy', 'valence']:
    stat, p_value = stats.mannwhitneyu(
        billboardData[feature], 
        spotifyData[feature],
        alternative='two-sided'
    )
    print(f"{feature}: p-value = {p_value:.4f} {'(significant)' if p_value < 0.05 else '(not significant)'}")
# Out:
# danceability: p-value = 0.6072 (not significant)
# energy: p-value = 0.0577 (not significant)
# valence: p-value = 0.0781 (not significant)

# %% [markdown]
# ### Statistical Comparison: Billboard Hot 100 vs Spotify Wrapped (Mann-Whitney U Test)
#
# A comparison table and Mann-Whitney U test were performed to determine whether
# the audio features of Billboard Hot 100 songs are statistically significantly
# different from the 2025 Spotify Wrapped songs.
#
# The means across both datasets are notably similar:
# - Danceability: Billboard (0.667) vs Spotify Wrapped (0.682), difference of -0.014
# - Energy: Billboard (0.685) vs Spotify Wrapped (0.647), difference of +0.038
# - Valence: Billboard (0.600) vs Spotify Wrapped (0.666), difference of -0.066
#
# The Mann-Whitney U test confirmed that none of the three features showed
# statistically significant differences:
# - **Danceability**: p-value = 0.607 (not significant)
# - **Energy**: p-value = 0.058 (not significant, but approaching significance)
# - **Valence**: p-value = 0.078 (not significant, but approaching significance)
#
# The absence of statistically significant differences across all three features
# suggests that Billboard Hot 100 songs share very similar audio characteristics
# to 2025 Spotify Wrapped songs. This suggests that Billboard chart performance may be a strong confounding variable in explaining what appeared on the 2025 Spotify Wrapped list.

# %% [markdown]
# #### Summary of Findings: Billboard Top 100 Confounding Variable Exploration
#
# When we combined the analysis of the Billboard Hot 100 historical data (2000–2023) and results from the Mann-Whitney U test, there are long term trends which support our hypothesis that music popularity trends show repeating patterns and that the three variables we've chosen have similarities in the trends highlighted within our analyiss.
#
# Analyzing the danceability variable across the datasets demonstrates a cluster between 0.6 and 0.75. This indicates a highly diverse array of dance tempos. Energy variable has a pronounced left-skewed distribution that is concentrated between 0.6 and 0.9. A steep drop-off occurs below the 0.4 mark, proving that high acoustic intensity is a foundational necessity for historical hits. Additionally, examining valence, this variable presents a uniform distribution across a 0.2 to 0.9 range. This reflects lack of significance.Similar to previous findings in our core dataset, cross-examinations with all three variables confirm these variables are independent.
#
# Despite slight visual differences in distribution curves, the Mann-Whitney U test confirms that audio profiles of the datasets are closely aligned across both datasets. For the danceability variable, the historical average (0.667) on the Billboard Hot 100 sits less than 2% lower than Spotify Wrapped (0.682). The p-value of 0.607 shows that there is no statistical significance. For the energy variable, the Billboard Hot 100 skews slightly higher (+0.038). The resulting p-value of 0.058 is closer to representing a statistical significant factor, but still falls short. For the valence variable,  Spotify tracks skew marginally happier (+0.066) and this difference does nto demonstate as statistical significance with a p-value of 0.078.
#
# In conclusion, Billboard Hot 100 presence acts as a confounding variable for the success of songs on the Spotify Wrapped. In addition to this key finding, the Billboard Hot 100 also demonstrates that the same trends are recurring which is a strong support for songs to be able to make a "comeback".

# %% [markdown]
# ### TikTok Confounding Variable Analysis
#
# In this section we explore TikTok virality as a potential confounding variable
# that may have influenced which songs appear on the 2025 Spotify Wrapped list.
# Using the TikTok Popular Songs dataset (2020-2022), which captures the audio
# characteristics of globally trending TikTok songs across three consecutive years,
# we will compare the danceability, energy, and valence of TikTok trending songs
# against those of the 2025 Spotify Wrapped songs. If TikTok consistently promoted
# songs with similar audio characteristics across 2020-2022, and those
# characteristics align with the 2025 Spotify Wrapped songs, this would suggest
# that TikTok virality may have played a role in shaping what became popular enough
# to appear on the 2025 Spotify Wrapped list.

# %%
tiktokData = pd.read_csv('data/02-processed/tiktok_final.csv')
tiktokData.head()
# Out:
#                          track_name          artist_name  danceability  \
# 0                            Say So             Doja Cat         0.787
# 1                   Blinding Lights           The Weeknd         0.514
# 2  Supalonely (feat. Gus Dapperton)                BENEE         0.862
# 3                            Savage  Megan Thee Stallion         0.843
# 4                Moral of the Story                 Ashe         0.572
#
#    energy  valence  acousticness  year
# 0   0.673    0.779       0.26400  2020
# 1   0.730    0.334       0.00146  2020
# 2   0.631    0.841       0.29100  2020
# 3   0.741    0.680       0.02520  2020
# 4   0.406    0.265       0.58700  2020

# %%
tiktokPairwise = sns.pairplot(tiktokData,
                              vars = ['danceability', 'energy', 'valence']
)
plt.show()

# %% [markdown]
# The pair plot reveals that danceability is strongly left-skewed, with most
# TikTok trending songs clustering between 0.6-0.8, confirming that highly
# danceable songs dominate TikTok. Energy and valence show more normal
# distributions centered around 0.6 and 0.5 respectively. The scatter plots
# show no strong linear relationships between any of the three variables,
# suggesting they measure independent musical characteristics.

# %%
corr = tiktokData[['danceability', 'energy', 'valence', 'acousticness']].corr()
sns.heatmap(corr, annot = True, cmap = 'Blues')

plt.title('Correlation Heatmap of TikTok Song Features')
plt.show()

# %% [markdown]
# The correlation heatmap confirms weak relationships between all audio features.
# The strongest correlation is between danceability and valence (0.29), suggesting
# that more danceable TikTok songs tend to be slightly more positive. Energy and
# acousticness show the strongest negative correlation (-0.47), which is expected
# since acoustic songs tend to be less intense. Overall the weak correlations
# confirm that each variable contributes independently to a song's TikTok appeal.

# %%
sns.histplot(
    data = tiktokData,
    x = 'danceability',
    bins = 20,
    kde = True
)

plt.title('Distribution of Danceability in TikTok Songs')
plt.show()

# %% [markdown]
# The distribution of danceability is left-skewed with a peak around 0.72,
# confirming that TikTok trending songs are overwhelmingly highly danceable.
# Very few songs below 0.4 danceability appear in the dataset, suggesting that
# low danceability is a barrier to TikTok virality. This aligns with TikTok's
# own statement that their community gravitates toward songs that are danceable
# and energetic.

# %%
sns.scatterplot(
    data = tiktokData,
    x = 'energy',
    y = 'danceability',
    hue = 'valence'
)

plt.title('Energy vs Danceability')
plt.show()

# %% [markdown]
# The scatter plot of energy vs danceability colored by valence shows that the
# majority of TikTok trending songs cluster in the high energy (0.6-0.9) and
# high danceability (0.6-0.9) range. Songs with higher valence (lighter colors)
# are spread across the cluster while lower valence songs (darker colors) also
# appear frequently, suggesting that emotional positivity is less of a requirement
# for TikTok virality than danceability and energy.

# %%
yearly_means = tiktokData.groupby('year')[['danceability', 'energy', 'valence']].mean()

# plot with discrete years
plt.figure(figsize=(8, 5))
plt.plot([2020, 2021, 2022], yearly_means['danceability'], marker='o', label='danceability')
plt.plot([2020, 2021, 2022], yearly_means['energy'], marker='o', label='energy')
plt.plot([2020, 2021, 2022], yearly_means['valence'], marker='o', label='valence')

plt.xticks([2020, 2021, 2022])
plt.xlabel('Year (TikTok Trending Year)')
plt.ylabel('Average Value')
plt.title('Average TikTok Song Features by Trending Year')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The line chart shows the average audio features of TikTok trending songs
# across the three years captured in our dataset (2020, 2021, 2022), where
# year represents when songs were trending on TikTok rather than their release
# year. Danceability remained consistently high (~0.71-0.73) across all three
# years with minimal variation. Energy showed a gradual increase from 0.61 in
# 2020 to 0.68 in 2022, while valence peaked at 0.56 in 2021 before declining
# to 0.51 in 2022. The consistency of danceability across all three years is
# particularly notable. Regardless of which year songs were trending, TikTok
# consistently promoted highly danceable music, supporting our argument that
# TikTok virality promotes a specific audio profile that may have influenced
# what appeared on the 2025 Spotify Wrapped list.

# %%
# Create comparison table
comparison = pd.DataFrame({
    'TikTok (2020-2022)': tiktokData[['danceability', 'energy', 'valence']].mean(),
    'Spotify Wrapped 2025': spotifyData[['danceability', 'energy', 'valence']].mean(),
    'Difference': tiktokData[['danceability', 'energy', 'valence']].mean() - spotifyData[['danceability', 'energy', 'valence']].mean()
})

print(comparison.round(3))
# Out:
#               TikTok (2020-2022)  Spotify Wrapped 2025  Difference
# danceability               0.717                 0.682       0.036
# energy                     0.653                 0.647       0.006
# valence                    0.536                 0.666      -0.129

# %%
# Mann-Whitney U test for each feature
for feature in ['danceability', 'energy', 'valence']:
    stat, p_value = stats.mannwhitneyu(
        tiktokData[feature], 
        spotifyData[feature],
        alternative='two-sided'
    )
    print(f"{feature}: p-value = {p_value:.4f} {'(significant)' if p_value < 0.05 else '(not significant)'}")
# Out:
# danceability: p-value = 0.0471 (significant)
# energy: p-value = 0.5491 (not significant)
# valence: p-value = 0.0000 (significant)

# %% [markdown]
# ### Statistical Comparison: TikTok vs Spotify Wrapped (Mann-Whitney U Test)
#
# A Mann-Whitney U test was performed to determine whether the audio features
# of TikTok trending songs (2020-2022) are statistically significantly different
# from the 2025 Spotify Wrapped songs.
#
# - **Danceability**: p-value = 0.047 (significant). TikTok trending songs
#   have statistically significantly higher danceability (mean = 0.717) compared
#   to Spotify Wrapped songs (mean = 0.682), suggesting TikTok promotes slightly
#   more danceable songs than what ended up on Spotify Wrapped.
#
# - **Energy**: p-value = 0.549 (not significant). There is no statistically
#   significant difference in energy between TikTok trending songs (mean = 0.653)
#   and Spotify Wrapped songs (mean = 0.647), suggesting both lists share similar
#   energy levels.
#
# - **Valence**: p-value < 0.001 (significant). TikTok trending songs have
#   statistically significantly lower valence (mean = 0.536) compared to Spotify
#   Wrapped songs (mean = 0.666), suggesting that while TikTok promotes more
#   emotionally neutral songs, the 2025 Spotify Wrapped list skewed more positive.
#
# Overall, the results suggest a partial overlap between TikTok and Spotify Wrapped
# audio profiles. The shared energy levels support the argument that TikTok virality
# may have influenced Spotify Wrapped, while the differences in danceability and
# valence suggest other factors also played a role in determining what appeared on
# the 2025 Spotify Wrapped list.

# %% [markdown]
# ### Summary of Findings: TikTok Confounding Variable
#
# The analysis of TikTok trending songs (2020-2022) reveals a partial but
# meaningful overlap with the audio characteristics of the 2025 Spotify Wrapped
# list, supporting our argument that TikTok virality may have acted as a
# confounding variable in shaping music popularity.
#
# Across three consecutive years, TikTok consistently promoted highly danceable
# songs (mean danceability = 0.717), with energy and valence remaining relatively
# stable, suggesting TikTok has a distinct and consistent audio profile that it
# promotes regardless of year. The Mann-Whitney U test confirmed that energy levels
# between TikTok trending songs and Spotify Wrapped songs are not statistically
# significantly different (p = 0.549), indicating that the intensity and activity
# level of songs popular on TikTok closely mirrors what appeared on the 2025
# Spotify Wrapped list.
#
# However, statistically significant differences were found in danceability
# (p = 0.047) and valence (p < 0.001). TikTok trending songs were slightly more
# danceable and notably less positive (valence mean = 0.536) compared to Spotify
# Wrapped songs (valence mean = 0.666). This suggests that while TikTok virality
# likely contributed to the popularity of high energy songs on Spotify Wrapped,
# it does not fully account for the emotional positivity found in 2025 Spotify
# Wrapped songs, indicating that other factors beyond TikTok virality also
# influenced what made it onto the list.
#
# Overall, TikTok virality is a partial but not complete explanation for what
# appeared on the 2025 Spotify Wrapped list, and should be considered.

# %% [markdown]
# ### Statistical Analysis: Do 2025 Spotify Wrapped Songs Share Significant Audio Similarities by Release Year?

# %%
def assign_era(year):
    if year < 2022:
        return 'Pre-2022'
    elif year == 2022 or year == 2023:
        return '2022-2023'
    else:
        return '2024'

spotifyData['era'] = spotifyData['release_year'].apply(assign_era)
print(spotifyData['era'].value_counts())
# Out:
# era
# 2024         32
# 2022-2023    10
# Pre-2022      8
# Name: count, dtype: int64

# %%
# separate each era group
pre_2022 = spotifyData[spotifyData['era'] == 'Pre-2022']
era_2022_2023 = spotifyData[spotifyData['era'] == '2022-2023']
era_2024 = spotifyData[spotifyData['era'] == '2024']

# Kruskal-Wallis test for each feature
for feature in ['danceability', 'energy', 'valence']:
    stat, p_value = stats.kruskal(
        pre_2022[feature],
        era_2022_2023[feature],
        era_2024[feature]
    )
    print(f"{feature}: H-statistic = {stat:.4f}, p-value = {p_value:.4f} {'(significant)' if p_value < 0.05 else '(not significant)'}")
# Out:
# danceability: H-statistic = 3.4632, p-value = 0.1770 (not significant)
# energy: H-statistic = 2.6427, p-value = 0.2668 (not significant)
# valence: H-statistic = 1.5218, p-value = 0.4672 (not significant)

# %% [markdown]
# ### Era Grouping
# Due to the uneven distribution of release years in our dataset (32 songs from
# 2024, 9 from 2023, and only scattered songs from earlier years), release years
# were grouped into three eras for statistical analysis:
# - **Pre-2022**: 8 songs (1985-2021)
# - **2022-2023**: 10 songs
# - **2024**: 32 songs
#
# ### Kruskal-Wallis Test Results
# A Kruskal-Wallis test was performed to determine whether danceability, energy, and valence differ significantly across release year eras:
#
# - **Danceability**: H = 3.463, p = 0.177 (not significant)
# - **Energy**: H = 2.643, p = 0.267 (not significant)
# - **Valence**: H = 1.522, p = 0.467 (not significant)
#
# None of the three audio features showed statistically significant differences across release year eras (all p > 0.05). This means that songs on the 2025 Spotify Wrapped list share similarly high danceability, energy, and valence regardless of whether they were released before 2022, in 2022-2023, or in 2024.
#
# ### Interpretation
# The absence of statistically significant differences across eras actually supports our comeback hypothesis; Songs from older release years that made it onto the 2025 Spotify Wrapped list share the same audio features as recently released songs. This suggests that the audio characteristics of danceability, energy, and valence are consistent predictors of popularity regardless of release year, and that older songs with these characteristics are equally capable of achieving mainstream success with newer releases.
#
# However, It is important to note that these results should be interpreted with caution given the small and uneven group sizes, particularly the Pre-2022 (n=8) and 2022-2023 (n=10) groups. A larger dataset would provide more reliable statistical conclusions.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  > Users are given the opportunity to consent to the sharing of their information when they sign up for the Apotify platform. Once the data is gathered, Spotify allows the anonymized data set to be available for research. The data is anonymized such that important Personally Identifying Information is not shared outside of the Spotify platform and allows for researchers and other data anlaysts to analyze the data. Artists also provide consent to the usage of their data and the aggregate data provided by Spotify when they agree to license their artistic works on the Spotify platform.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  > In our background research, several issues around accuracy of the data were raised, including the use of AI to do performatice analysis of the data to produce the final consumer facing product. While there is some collection bias due to Spotify's usage of AI and an insular platform that users provide their data, the data contains standardized measurements and structural methods of analyzing the data. One step that we will take to mitigate the risk is to examine streaming numbers separately from our main data set because these were highlighted in our backgroudn research as a problematic area that can sometimes be artificially inflated.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  > In our background research, we discovered that the data set we want to use is anonymized from the Spotify platform and this limits the PII exposure.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#  > From our background research, the streaming volume is the most problematic of the numbers annd variables. As a result, we will examine this variable separately as a potential argument around popularity or creation of trends given the publicly available criticism uncovered in our background research.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  > We will use our project Github repo to help manage access to our data sets, models, and analysis which has access controls to just our group and the class instructors and TAs.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  > The data is anonymized such that we do not need to address the Right to Be forgotten process or other data deletion requests using our current data set.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#  > After the formal submission of this project we will retain the original analysis and data for 30 days and then the Data project amanger, Dellaena Maliszewski, will conduct the deletion.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  > From our background research, we pulled additional academic articles from inside and outside of academia that provide a more hollistic view of the perception of Spotify Wrapped data, it's implications, and we have also included naysayers/critics of Spotify Wrapped so that we can understand any additional factors that might influence our analysis.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  > From our background research, we identified a few areas of concern for informational bias around the number of streams as an indicator of popularity becasue this data can get artificially inflated. As a result, we will examine these factors separately and with additional bias through our analysis
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  > In order to achieve this, we plan to separate out controversial numbers which have a documented comments about the inaccuracies such as the number of streams variable where we will make annotations in our graphs and visualization. Additionally, our core variables related to our hypothesis are generated within the Spotify platform (danceability, energy, valence and release date). This separation and annotations will ensure that the representations closest to our main hypothesis are as close to standardized as possible.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  > Our data set is anonymized and does not contain PII.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#  > We will create a step by step documentation of our analysis, process, and definitions throughout our project such that our work is repeatable and auditable.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  > We have examined the specific variables and for those variables where we have found examples of bias or potential artifical inflation (i.e. number of streams) we will add annotations on our visualizations and examine these factors as supportive evidence, but not core evidence on whether we can accept or reject our hypothesis.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  > For our data set, we are using core variables provided and evaluated by the Spotify fetatures in examining our core hypothesis (danceability, energy, valence, release date) where there are documented methods to be able to understand how these variables are standardized within the Spotify platform. Tertiary variables whcih could be subject to artifical inflation, i.e. number of streams, will include notes and annotations when visualized or considered.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  > We have selected standardized auto-generated variables from the Spotify platform, but have also considered other variables such as number of streams and potentially genre as ways to further explore the breakdown of the data and provide supportive analysis for our hypothesis.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  > All of our variables have compelte descriptions and, from our background research, there are [specific models](https://www.hudsong.dev/spotify-wrapped-2024-data-analysis) for how Spotify Wrapped works and how our chosen variables are formulated which assist in our understanding and ability to apply the variables for analysis.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#  > Our plan to address communicating limitations is to add annotations in our visualizations as well as any potential citations regarding variables or data which has gotten publically available criticism. In our background research, we identified specific variables, i.e. number of streams, where there is public available criticism on it's accuracy and we will add these limitations into our visualizatons and annotations.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  > Our initial chosen data set is a static, publicly avalable data set and therefore the Data Team project manager, Dellaena Maliszewski, will monitor and regularly audit the useability of the data for analysis.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  > We have considered the fact that artists or other participants in the original data set might experience reputational harm if the data demonstrates negative results from our analysis. Our plan to address this is to add annotations, ex. For Educational purposes only, throughout our analysis, visualizations, and throughout our study to ensure that there is no additional confusion as to whether our results represent a more official position abotu Artists, music, release dates, or quality of the music and Spotify Wrapped.
#
# - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#  > We have established access controls to be able to contain access to our data, model, and analysis which would prevent unintended access. Data will also get deleted by the Data project manager, Dellaena Maliszewski, 30 days after the project has been formally submitted.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Team Expectation 1:* All team members will provide active feedback and involvement with the project during weekly check-ins as prescribed by the provided timeline.
# * *Team Expectation 2:* All team members will communicate via the [Group Discord Channel](https://discord.com/channels/1488346548776603759/1488346990818496724) and respond within 48 hours to questions or issues raised in the channal.
# * *Team Expecation 3:* All team members will communicate 48 hours in advance of a due date in the event that they are not able to complete their section or the tasks originally aligned and agreed to.
# * *Team Expecation 4:* All team members will use AI as allowed by this course, cite their sources or models, and make all team members aware of it's usage (when, where, how and verifiable results) and sections produced or influenced by AI are subject to final approval of the team for inclusion in this project.
# * *Team Expectation 5:* All team members will provide sources for all of their data and any information that supports specific points of view throughout the proposal which are not their own work to ensure citations and integrity
# * *Team Expectation 6:* Data team will provide analysis team with background, context, and story points to help uplift and translate the information to specific and actionable insights that support the validation or invalidation of our hypothesis
# * *Team Expectation 7:* Team members will provide respectful, professional feedback when communicating to each other in the [Group Discord Channel](https://discord.com/channels/1488346548776603759/1488346990818496724) or in any other format.
# * *Team Expectation 8:* Analysis team will use data as specifically provided by the data team and, if insufficient, then the Analysis team will ask questions at least 24 hours in advance of the next checkpoint and final project.
# * *Team Expectation 9:* All Team members will particiapte in the final video deliverable except in the case of a medical emergency or similar instance where the team member will actively notify the rest of the team at least 24 hours in advance of the final exercise on 6/9.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# ### Upcoming
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 5/18  | 1 PM - 5PM   | Q&A with Analysis Team and prep Data in for analysis team with story points with complete shareout (Daira, Gianna, Dellaena)| |
# | 5/19  | 4 PM - 5PM   | Review/Edit wrangling/EDA (ALL); Discuss Analysis Plan and video fianlization (Tamika, Anushka) | |
# | 5/20  | 3 PM - 5PM   | EDA Checkpoint preparation: Analysis and Visuals (Tamika, Anushka)| Plan for the video and detail shareout for the group (Anushka)|
# | 5/25  | 4 PM - 5PM   | Discussion and additional edits needed in preparationg for the EDA Checkpoint (ALL) | Video plan finalized (Anushka) |
# | 5/26  | 4 PM - 5PM   | EDA Checkpoint preparation (TBD) and submission (TBD) & Group Progress Survey (ALL) | Discuss/edit any additional ED Checkpoint needs and updates before final submission (ALL) |
# | 5/27  | 4 PM - 5PM   | EDA Checkpoint read through (Tamika and Anushka)| Data Review and analysis read through (Gianna, Daira, Dellaena) |
# | 5/27  | Before 11:59 PM  | EDA Checkpoint preparation and submission (TBD)| Video review and final logistics and updates before Final Project due date |
# | 5/28  | 4 PM - 5PM   | Discussion and additional edits needed in preparationg for the EDA Checkpoint (ALL) | Video plan finalized (Anushka) |
# | 5/29  | 4 PM - 5PM   | EDA Checkpoint preparation (TBD) and submission (TBD) & Group Progress Survey (ALL) | Discuss/edit any additional ED Checkpoint needs and updates before final submission (ALL) |
# | 6/2  | 4 PM - 5PM   | EDA Checkpoint feedback corrections (Tamika and Anushka)| Data Review feedback and corrections (Gianna, Daira, Dellaena) |
# | 6/3  | 4 PM - 5PM   | Final Project analysis Rough Draft (Tamika and Anushka)| Final Project Data Rought Draft Review (Gianna, Daira, Dellaena) |
# | 6/5  | 4 PM - 5PM   | Final Project analysis Dry-run (Tamika and Anuska) - Video script (Anushka)| Final Project Data Dry run ((Gianna, Daira, Dellaena)) |
# | 6/8  | 4 PM - 5PM   | Final Project read through (Tamika and Anushka)| Data Review and analysis read through and finalization (Gianna, Daira, Dellaena) |
# | 6/9  | 4 PM - 5PM   | Final Project video exercise (ALL)| |
# | 6/10  | Before 11:59 PM  | Turn in Final Project, Group Project Surveys, Group Progress Survey| Debrief & Feedback |
#
# ### Completed
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 4/28  | 4 PM - 5PM  | Create Proposal ideas, discussion on logistics and timing | Discuss roles and responsibilities and regular meeting cadences with the goal to submit final project proposal |
# | 5/5   |  4 PM - 5PM  | Background research on topic (Daira) and propose data sources (ALL) | Writing/Analysis Team: Review format for final product and discuss data points needed (Tamika, Anushka) Data Team: Discuss ideal dataset(s) and additional data needs in prep for Data Checkpoint (Daira, Gianna, Dellaena) |
# | 5/12  | 4 PM - 5PM    | Data Checkpoint preparation (Daira, Gianna, Dellaena) and submission (Dellaena) & Group Progress Survey (ALL) | Discuss data and research needs and assign roles and responsibilities to analysis, data gathering, and summarization |
# | 5/13  | Before 11:59 PM  | Data checkpoint submission (Dellaena) | Review/Edit and data wrangling (Daira, Gianna, Dellaena); Feedback (ALL) |
