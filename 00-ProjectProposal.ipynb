# %% [markdown]
# ### Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline.   This cell is for your reference only and is not needed in your report.
#
# **Scoring:** Out of $10$ points
#
# - Each Developing => $-1$ pts
# - Each Unsatisfactory/Missing => $-2$ pts
# 	- until the score is 0
#
# If students address the detailed feedback in a future checkpoint, they will **earn these points back**.
#
#
# |                   | Unsatisfactory                                                                                                                                                                                                                                                                                    | Developing                                                                                                                                                                                                                                                                                                                                   | Proficient                                                                                                                                                                                                                                                    | Excellent                                                                                                                                                                                                                                                                                                                      |
# |-------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Research question | The research issue remains unclear. The research purpose, questions, hypotheses, definitions variables, and controls are still largely undefined, or when they are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | The research issue is identified, but the statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables, and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported by the research and theoretical literature. All elements are mutually supportive. |
# | Background        | Did not have at least 2 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                         | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                                    | Key research components were connected to relevant, reliable theoretical and research literature.                                                                                                                                                             | The narrative integrates critical and logical details from the peer-reviewed theoretical and research literature. Each key research component is grounded in the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                      |
# | Hypothesis        | Lacks most details; vague or interpretable in different ways. Or seems completely unrealistic.                                                                                                                                                                                                    | A key detail to understand the hypothesis or the rationale behind it was not described well enough                                                                                                                                                                                                                                           | The hypothesis is clear. All elements needed to understand the rationale were described in sufficient detail                                                                                                                                                  | The hypothesis and its rationale were described succinctly and with clarity about how they are connected to each other                                                                                                                                                                                                         |
# | Data              | Did not describe ideal dataset fully AND does not include at least one reference to an external source of data.                                                                                                                                                                         | Either does not describe the ideal dataset fully OR does not include at least one reference to an external source of data that could be used to answer the proposed question.                                                                                                                                                                                                                                                            | Ideal dataset(s) well-described and includes everything needed for answering question(s) posed. Includes at least one reference to a source of data that would be needed to fully answer the question proposed.                                                                                                                                                            | Ideal dataset(s) well-described and includes everything needed for answering question(s) posed. Includes references to all sources of data that would be needed to fully answer the question proposed. The details of the descriptions also make it clear how they support the needs of the project and discuss the differences betweeen the ideal and real datasets.                                                                                                                       |
# | Ethics            | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                                                          | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                               | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Team expectations | Lack of expectations                                                                                                                                                                                                                                                                              | The list of expectations feels incomplete and perfunctory                                                                                                                                                                                                                                                                                    | It feels like the list of expectations is complete and seems appropriate                                                                                                                                                                                      | The list clearly was the subject of a thoughtful approach and already indicates a well-working team                                                                                                                                                                                                                            |
# | Timeline          | Lack of timeline. Or timeline is completely unrealistic                                                                                                                                                                                                                                           | The timeline feels incomplete and perfunctory. The timeline feels either too fast or too slow for the progress you expect a group can make                                                                                                                                                                                                   | It feels like the timeline is complete and appropriate. it can likely be completed as is in the available amount of time                                                                                                                                      | The timeline was clearly the subject of a thoughtful approach and indicates that the team has a detailed plan that seems appropriate and completeable in the allotted time.                                                                                                                                                    |

# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# * Tamika Hsieh: Project management (Analysis Write-up, Video), Writing - drafting, Data visualization, Summarization & Analysis
# * Anushka Joshi: Background Research, Writing - drafting, visulization, Video preparation
# * Daira: Merino: Coding & Data gathering, Analysis, Visualization
# * Gianna Hester: Coding & Data gathering, backgroudn research, Video preparation
# * Dellaena Malsizewski: Project Management (Data), coding, data wrangling and gathering, background research

# %% [markdown]
# ## Research Question

# %% [markdown]
# Every year in December 6 million Spotify users get a list called "Spotify Wrapped" which highlights the 100 most played songs by Spotify users during the year regardless of the song's release date. The struggling music industry invests in teams of analysts who use Spotify Wrapped data to understand music, cultural and data trends that could indicate the "next big comeback" of songs or artists from certain publishing years. These songs are measured using the Spotify audio feature 0.0–1.0 using the following categories: danceability (how easy it is to dance to), energy (intensity and activity during the song), and valence (musical positivity throughout the song). We will use these variables as well as the following variables: Release date (release_year), to answer the following question:
#
# In 2025, do the top 100 songs included in the 2025 Spotify Wrapped list share statistically signficant similarities in danceability, valence, and energy according to their release date which could indicate a potential "comeback"?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# three to six paragraphs of background information here and a *minimum* of three relevant citations.
#
# 1. Origin of Spotify, what is it : https://support.spotify.com/us/article/what-is-spotify/
#      - Origin of Spotify Wrapped: https://medium.com/@candice.katz/the-origin-and-evolution-of-spotifys-wrapped-ab44805bfb93
#         - How it works: https://www.hudsong.dev/spotify-wrapped-2024-data-analysis
#         - Analysis on how Spotify pulled it off: https://engineering.atspotify.com/2021/02/how-spotify-optimized-the-largest-dataflow-job-ever-for-wrapped-2020
#      - Significance of of SW: https://www.forbes.com/sites/conormurray/2023/11/28/spotify-wrapped-2023-comes-soon-heres-how-it-became-a-viral-and-widely-copied-marketing-tactic/
# 2. Naysayers:
#     - Complications with SW data: https://www.news-journalonline.com/story/entertainment/music/2025/12/03/spotify-wrapped-apple-music-wrong-why/87584135007/?gnt-cfr=1&gca-cat=p&gca-uir=false&gca-epti=z116580p000150c000150e116580v000149&gca-ft=202&gca-ds=sophi, https://www.vogue.com.au/culture/features/spotify-wrapped/news-story/02124c529cf3ace24ed5f673e5b1f3b9
#     - Why Spotify wrapped is a joke (https://www.theguardian.com/music/2023/nov/30/spotify-wrapped-is-creepy-meaningless-and-shows-just-how-much-data-big-tech-has-on-you)
#         - Algorithmic and Inaccurate Data: Users frequently report inaccurate stats, noting that the algorithm favors shorter songs over longer ones, favoring frequency over total listening time. It may promote songs the platform wanted you to hear rather than reflecting genuine favorites.
#         -   Creepy Data Mining: Critics call it a "meaningless" marketing exercise that highlights how much data Spotify gathers, raising concerns about privacy and surveillance.
#         - Low Artist Pay: Critics point out that Wrapped trends hide the reality that many artists are not paid well by the platform.
#         -   Uninspired Presentation (2024): Users felt recent Wrapped campaigns, particularly in 2024, lacked creativity, using "one-dimensional visuals" and generic AI features rather than personalized insights.
#         - AI Dependency: The heavy reliance on AI for insights, such as the AI DJ or "Gen AI" commentary, makes the results feel impersonal and superficial, lacking human context.
#         - Inaccuracies: Some users reported that the tracking is off, with reports of impossible listening times, such as over 1,440 minutes in a single day.
# 3. Why Now? (Informed by previous studies that we want to include)
#     - Sense of self and personal brand, hyper social mobility on digital platforms with generations growing up on the web
#     OR
#     - The music industry is struggling with a broken economic model where rising touring costs, high inflation, and low streaming payouts make it difficult for artists to survive, despite a "golden age" of live performance revenue for top acts. The industry is grappling with the aftermath of the pandemic, with many independent venues facing losses due to rising expenses and predatory ticket practices.  https://rocknheavy.net/the-music-industry-is-broken-theres-no-coming-back-unless-things-change-ea1f9a5557c8
#             -  Benefits of Spotfy Wrapped Data for Artists: https://newsroom.spotify.com/2025-12-03/wrapped-for-artists-songwriters-creators-authors-advertisers/
#         - it molds and shapes the music industry
# 4. & 5. Previous Analysis, Datasets and Studies:
#     Two main themes: Value of SW to the music industry, SW as a reflection of ourselves
#     - https://irrationallabs.com/blog/spotify-wrapped-behavioral-science/. ;
#     - Behavioral Science & Psychology: Wrapped taps into the "quantifiable self" phenomenon, where users enjoy measuring their habits. It utilizes social      comparison (e.g., "top 1% of fans") and validates identity, allowing users to share a curated version of their musical taste.
#     Viral Marketing Strategy: The campaign, often dubbed a "masterclass in marketing," generates massive organic engagement (e.g., over 60 million shares in 2020) by creating shareable, aesthetic, and customized visuals. It creates a "Fear of Missing Out" (FOMO) and a sense of community around a shared, yet personal, annual experience.
#     Data Methodology: Wrapped tracks data from Jan 1st to mid-November. It filters out white noise, defines top songs by those played for over 30 seconds, and uses weighted counts for top artists to prioritize primary artists over features.
#         Themes of Analysis: Studies, including An algorithmic event: The celebration and critique of Spotify..., have identified key themes:
#         Resonance: Users celebrate the personal reflection.
#         Limits: Some feel the "Wrapped self" is a limited, algorithmically curated version of their tastes.
#         Ambience: A focus on how music fits into daily life (e.g., focus, workout).
#         Critique: Discussions on data privacy and the commercialization of personal music habits.
#     - Community: Linking users to others with similar tastes, notes Psychology and marketing behind Spotify wrapped.  https://www.youtube.com/watch?v=ppUoGh-y_Xo
#     - "Algorithmic self-making and performances of taste on Spotify Wrapped" (Jacobsen & Beer, 2026): Explores how Wrapped acts as an "algorithmic event," blending personal, anticipated records of music consumption with social, public performance.
#         - https://eprints.whiterose.ac.uk/id/eprint/240195/1/Wrap%20your%20head%20around%20it%20%20algorithmic%20self-making%20and%20performances%20of%20taste%20on%20Spotify%20Wrapped.pdf
#     - "An algorithmic event: The celebration and critique of Spotify Wrapped" (Sage Journals, 2025): Analyzes how users and scholars engage with Wrapped, focusing on the tension between data-driven insights and the perceived "truth" of personal taste.
#     - "Spotify (Un)wrapped: how ordinary users critically reflect on Spotify's datafication of the self within creative workshops" (Annabell & Rasmussen, 2024): Examines user reflections on how Spotify turns personal behavior into data stories ("datafication of the self").
#         - https://journals.sagepub.com/doi/10.1177/14614448251391301
#     - "Your Wrapped doesn’t lie”: Data realism and Spotify’s constructions of listening" (2026): Discusses how Wrapped portrays listening data as an authentic reflection of the self and a "data realist" construction of tastes.
#         - https://journals.sagepub.com/doi/10.1177/14614448261422367
#     - "Facing the Music: Spotify Wrapped as a Determinant for Personal Identity Performance" (Gartner, 2023): An undergraduate thesis exploring the linguistic performance of personal identity when sharing Wrapped stats.
#         - https://cdr.lib.unc.edu/concern/honors_theses/6h4413727
#     - "Spotify ‘Unwrapped’: An Exploration of Data-Based Value Generation on a Music Streaming Platform" (Adenuga, 2022): Investigates the value creation of Wrapped for Spotify, artists, and advertisers
#         - https://ischannel.lse.ac.uk/articles/198
#
#  **Use inline citation through HTML footnotes to specify which references support which statements**
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) *Spotify Support Article*. https://support.spotify.com/us/article/what-is-spotify/
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Greenberg, C. (10 Dec 2024) The origin and evolution of Spotify’s Wrapped *Medium*. https://medium.com/@candice.katz/the-origin-and-evolution-of-spotifys-wrapped-ab44805bfb93
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Also refs should be important to the background, not some randomly chosen vaguely related stuff. Include a web link if possible in refs as above.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# By analyzing and synthesizing the top 100 songs included in the 2025 Spotify Wrapped list, we believe the research will demonstrate that there are similarities between songs by release date. We also suspect that there will be certain confounding variables present such as the rise in popularity of TikTok which could potentially artifically positively influence the number of listens for certain artists present on the 2025 Spotify Wrapped list or account for outliers.

# %% [markdown]
# ## Data

# %% [markdown]
# The ideal dataset will have a complete and tidy data set from a given year with the following variables: variables that indicate the overall success factors such as number of streams, ratings (danceability, energy, and valence), as well as clearly defined release years. We will need at least 100 observations in order to collect a sample, which also represents the Top 100 Spotify Wrapped list. The data should be collected by Spotify, the originators of Spotify Wrapped, and available bia API such that we would be able to access the API to extract the data into a usable format suitable for analysis and visualization. The measurements should also be collected using Spotify measurements and internal tools to allow for consistency in the results and standardized measurement, in this case Spotify audio feature 0.0–1.0. The data should be stored in a clean and tidy database with clearly defined and obvious column names and descriptions that allow us to understand the meanings behind the columns and data.
#
# The following dataset is great for the use case of our project [Spotify Wrapped 2025 | Top Songs & Artists](https://www.kaggle.com/datasets/alitaqishah/spotify-wrapped-2025-top-songs-and-artists) and is located on Kaggle. There are no additional requirements in order to be able to use this dataset. The important variables (column names): release_year, danceability, energy, valence. Som additional variables that we might use are: peak_global_chart_position, acousticness, and streams_2025_billions to support our hypothesis around trending songs and likelihood that these songs are similar.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  > Users are given the opportunity to consent to the sharing of their information when they sign up for the Apotify platform. Once the data is gathered, Spotify allows the anonymized data set to be available for research. The data is anonymized such that important Personally Identifying Information is not shared outside of the Spotify platform and allows for researchers and other data anlaysts to analyze the data. Artists also provide consent to the usage of their data and the aggregate data provided by Spotify when they agree to license their artistic works on the Spotify platform.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  > In our background research, several issues around accuracy of the data were raised, including the use of AI to do performatice analysis of the data to produce the final consumer facing product. While there is some collection bias due to Spotify's usage of AI and an insular platform that users provide their data, the data contains standardized measurements and structural methods of analyzing the data. One step that we will take to mitigate the risk is to examine streaming numbers separately from our main data set because these were highlighted in our backgroudn research as a problematic area that can sometimes be artificially inflated.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  > In our background research, we discovered that the data set we want to use is anonymized from the Spotify platform and this limits the PII exposure.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#  > From our background research, the streaming volume is the most problematic of the numbers annd variables. As a result, we will examine this variable separately as a potential argument around popularity or creation of trends given it's
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  > We will use our project Github repo to help manage access to our data sets, models, and analysis which has access controls to just our group and the class instructors and TAs.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  > The data is anonymized such that we do not need to address the Right to Be forgotten process or other data deletion requests using our current data set.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#  > After the formal submission of this project we will retain the original analysis and data for 30 days and then the Data project amanger, Dellaena Maliszewski, will conduct the deletion.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  > From our background research, we pulled additional academic articles from inside and outside of academia that provide a more hollistic view of the perception of Spotify Wrapped data, it's implications, and we have also included naysayers/critics of Spotify Wrapped so that we can understand any additional factors that might influence our analysis.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  > From our background research, we identified a few areas of concern for informational bias around the number of streams as an indicator of popularity becasue this data can get artificially inflated. As a result, we will examine these factors separately and with additional bias through our analysis
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  > In order to achieve this, we plan to separate out controversial numbers which have a documented comments about the inaccuracies such as the number of streams variable where we will make annotations in our graphs and visualization. Additionally, our core variables related to our hypothesis are generated within the Spotify platform (danceability, energy, valence and release date). This separation and annotations will ensure that the representations closest to our main hypothesis are as close to standardized as possible.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  > Our data set is anonymized and does not contain PII.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#  > We will create a step by step documentation of our analysis, process, and definitions throughout our project such that our work is repeatable and auditable.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  > We have examined the specific variables and for those variables where we have found examples of bias or potential artifical inflation (i.e. number of streams) we will add annotations on our visualizations and examine these factors as supportive evidence, but not core evidence on whether we can accept or reject our hypothesis.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  > For our data set, we are using core variables provided and evaluated by the Spotify fetatures in examining our core hypothesis (danceability, energy, valence, release date) where there are documented methods to be able to understand how these variables are standardized within the Spotify platform. Tertiary variables whcih could be subject to artifical inflation, i.e. number of streams, will include notes and annotations when visualized or considered.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  > We have selected standardized auto-generated variables from the Spotify platform, but have also considered other variables such as number of streams and potentially genre as ways to further explore the breakdown of the data and provide supportive analysis for our hypothesis.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  > All of our variables have compelte descriptions and, from our background research, there are [specific models](https://www.hudsong.dev/spotify-wrapped-2024-data-analysis) for how Spotify Wrapped works and how our chosen variables are formulated which assist in our understanding and ability to apply the variables for analysis.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#  > Our plan to address communicating limitations is to add annotations in our visualizations as well as any potential citations regarding variables or data which has gotten publically available criticism. In our background research, we identified specific variables, i.e. number of streams, where there is public available criticism on it's accuracy and we will add these limitations into our visualizatons and annotations.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  > Our initial chosen data set is a static, publicly avalable data set and therefore the Data Team project manager, Dellaena Maliszewski, will monitor and regularly audit the useability of the data for analysis.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  > We have considered the fact that artists or other participants in the original data set might experience reputational harm if the data demonstrates negative results from our analysis. Our plan to address this is to add annotations, ex. For Educational purposes only, throughout our analysis, visualizations, and throughout our study to ensure that there is no additional confusion as to whether our results represent a more official position abotu Artists, music, release dates, or quality of the music and Spotify Wrapped.
#
# - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#  > We have established access controls to be able to contain access to our data, model, and analysis which would prevent unintended access. Data will also get deleted by the Data project manager, Dellaena Maliszewski, 30 days after the project has been formally submitted.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Team Expectation 1:* All team members will provide active feedback and involvement with the project during weekly check-ins as prescribed by the provided timeline.
# * *Team Expectation 2:* All team members will communicate via the [Group Discord Channel](https://discord.com/channels/1488346548776603759/1488346990818496724) and respond within 48 hours to questions or issues raised in the channal.
# * *Team Expecation 3:* All team members will communicate 48 hours in advance of a due date in the event that they are not able to complete their section or the tasks originally aligned and agreed to.
# * *Team Expecation 4:* All team members will use AI as allowed by this course, cite their sources or models, and make all team members aware of it's usage (when, where, how and verifiable results) and sections produced or influenced by AI are subject to final approval of the team for inclusion in this project.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 4/28  | 4 PM - 5PM  | Create Proposal ideas, discussion on logistics and timing | Discuss roles and responsibilities and regular meeting cadences with the goal to submit final project proposal |
# | 5/5   |  4 PM - 5PM  | Background research on topic (Daira) and propose data sources (ALL) | Writing/Analysis Team: Review format for final product and discuss data points needed (Tamika, Anushka) Data Team: Discuss ideal dataset(s) and additional data needs in prep for Data Checkpoint (Daira, Gianna, Dellaena) |
# | 5/12  | 4 PM - 5PM    | Data Checkpoint preparation (Daira, Gianna, Dellaena) and submission (Dellaena) & Group Progress Survey (ALL) | Discuss data and research needs and assign roles and responsibilities to analysis, data gathering, and summarization |
# | 5/13  | Before 11:59 PM  | Data checkpoint submission (Dellaena) | Review/Edit and data wrangling (Daira, Gianna, Dellaena); Feedback (ALL) |
# | 5/19  | 4 PM - 5PM    | Import & Wrangle Data (Daira, Gianna, Dellaena); EDA (Dellaena, Tamika) | Review/Edit wrangling/EDA (ALL); Discuss Analysis Plan and video fianlization (Tamika, Anushka) |
# | 5/26  | 4 PM - 5PM   | EDA Checkpoint preparation (TBD) and submission (TBD) & Group Progress Survey (ALL) | Discuss/edit any additional ED Checkpoint needs and updates before final submission (ALL) |
# | 5/27  | Before 11:59 PM  | EDA Checkpoint preparation and submission (TBD)| Video review and final logistics and updates before Final Project due date |
# | 6/10  | Before 11:59 PM  | Turn in Final Project, Group Project Surveys, Group Progress Survey| Debrief & Feedback |
